# %% [markdown]
# Consolidation Notebook
# This functions as consolidation of the generated sCurves for planned and actual.
# This will merge it to the full calendar for the computation of daily accomplishments averages
